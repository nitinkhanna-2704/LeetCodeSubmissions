# %% [markdown]
# ### 19. Remove Nth Node From End of List
#
# Given the head of a linked list, remove the nth node from the end of the list and return its head.

# %% [markdown]
# Input: head = [1,2,3,4,5], n = 2
# Output: [1,2,3,5]

# %%
from typing import Optional

# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def removeNthFromEnd(self, head: Optional[ListNode], n: int) -> Optional[ListNode]:
        dummy = ListNode(0, head)
        slow = dummy
        fast = dummy

        for _ in range(n + 1):
            fast = fast.next

        while fast:
            slow = slow.next
            fast = fast.next

        slow.next = slow.next.next
        return dummy.next

r = Solution().removeNthFromEnd(ListNode(1,ListNode(11,None)),)
print(r.val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 25
#      21
#      22         slow.next = slow.next.next
#      23         return dummy.next
#      24
# ---> 25 r = Solution().removeNthFromEnd(ListNode(1,ListNode(11,None)),)
#      26 print(r.val)
#
# TypeError: Solution.removeNthFromEnd() missing 1 required positional argument: 'n'
